# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
import matplotlib.pyplot as plt
import seaborn as sns
from CleaningClass import DataCleaning as dc

# %%
self = dc

# %%
file_path = r"C:\Users\Chris Napoli\OneDrive\Desktop\Analytics With ML\Final Project Repo\ProjectHawk2025\framingham_heart_study.csv"

# %%
df = dc.loadData(self, file_path)
# Out:
# Data loaded successfully from C:\Users\Chris Napoli\OneDrive\Desktop\Analytics With ML\Final Project Repo\ProjectHawk2025\framingham_heart_study.csv

# %%
dc.exploreData(df, self)
# Out:
# -------------------- Data Shape --------------------
# (4240, 16)
#
# -------------------- Data Head --------------------
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# ...

# %%
df.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %%
dc.detectOutliers(self, columnName="totChol", method="zscore", threshold=3.0)
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 194      0   42        3.0              0         0.0     0.0
# 543      1   47        2.0              1        18.0     0.0
# 617      0   51        3.0              1         3.0     0.0
# 998      0   57        1.0              0         0.0     NaN
# 1111     0   52        2.0              0         0.0     0.0
# 1150     0   46        1.0              1        10.0     0.0
# 1447     0   60        1.0              0         0.0     0.0
# 1544     1   42        1.0              1        20.0     0.0
# 1691     0   64        1.0              0         0.0     0.0
# 1937     0   59        1.0              0         0.0     0.0
# 2024     0   62        1.0              0         0.0     0.0
# 2206     1   46        1.0              1        15.0     0.0
# 2349     0   63        3.0              0         0.0     0.0
# 2368     0   54        2.0              1         5.0     0.0
# ...
